# %%
# import packages
import cv2
from keras.models import load_model
from keras.preprocessing.image import load_img, img_to_array
import numpy as np
import PIL
# Out:
# Using TensorFlow backend.

# %%
import tensorflow as tf
model = tf.keras.models.load_model("model.h5") # cnn

# model accept below hight and width of the image
img_width, img_hight = 200, 200

# %%
# Load the Cascade face Classifier
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#startt  web cam
cap = cv2.VideoCapture(0) # for webcam

img_count_full = 0

#parameters for text
# font 
font = cv2.FONT_HERSHEY_SIMPLEX 
# org 
org = (1, 1)
class_lable=' '      
# fontScale 
fontScale = 1 #0.5
# Blue color in BGR 
color = (0, 0, 255) 
# Line thickness of 2 px 
thickness = 2 #1

#sart reading images and prediction
while True:
    img_count_full += 1
    
    #read image from webcam
    responce, color_img = cap.read()
    
    
    #if respoce False the break the loop
    if responce == False:
        break    
    


    
    
    # Convert to grayscale
    gray_img = cv2.cvtColor(color_img, cv2.COLOR_BGR2GRAY)
    
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray_img, 1.3, 5)
    
    #take face then predict class mask or not mask then draw recrangle and text then display image
    img_count = 0
    for (x, y, w, h) in faces:
        org = (x-10,y-10)
        img_count +=1 
        color_face = color_img[y:y+h,x:x+w] # color face
#         img=cv2.resize(color_face,(img_width,img_hight))
        cv2.imwrite('faces/input/%d%dface.jpg'%(img_count_full,img_count),color_face)
        img = load_img('faces/input/%d%dface.jpg'%(img_count_full,img_count), target_size=(img_width,img_hight))
        
        img = img_to_array(img)/255
        img = np.expand_dims(img,axis=0)
        pred_prob = model.predict(img)
#         print(pred_prob[0][0].round(2))
        pred=np.argmax(pred_prob)
            
        if pred==0:
            print("User with mask - predic = ",pred_prob[0][0])
            class_lable = "Mask"
            color = (255, 0, 0)
            cv2.imwrite('faces/with_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                 
        else:
            print('user not wearing mask - prob = ',pred_prob[0][1])
            class_lable = "No Mask"
            color = (0, 255, 0)
            cv2.imwrite('faces/without_mask/%d%dface.jpg'%(img_count_full,img_count),color_face)
                
        cv2.rectangle(color_img, (x, y), (x+w, y+h), (0, 0, 255), 3)
        # Using cv2.putText() method 
        cv2.putText(color_img, class_lable, org, font,  
                                   fontScale, color, thickness, cv2.LINE_AA) 
    
    # display image
    cv2.imshow('LIVE face mask detection', color_img)
    
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the VideoCapture object
cap.release()
cv2.destroyAllWindows()
# Out:
# User with mask - predic =  0.990449
# User with mask - predic =  0.9860756
# User with mask - predic =  0.99401087
# User with mask - predic =  0.991411
# User with mask - predic =  0.99448305
# User with mask - predic =  0.9958092
# User with mask - predic =  0.99701846
# User with mask - predic =  0.9977608
# User with mask - predic =  0.9969669
# User with mask - predic =  0.9986401
# User with mask - predic =  0.9973084
# User with mask - predic =  0.9969254
# User with mask - predic =  0.98500603
# User with mask - predic =  0.9525753
# User with mask - predic =  0.99879444
# User with mask - predic =  0.9997321
# User with mask - predic =  0.9997236
# User with mask - predic =  0.9996468
# User with mask - predic =  0.9995963
# User with mask - predic =  0.9996131
# User with mask - predic =  0.9997516
# User with mask - predic =  0.9995541
